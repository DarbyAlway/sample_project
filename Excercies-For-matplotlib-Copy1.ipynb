# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot()
# Out:
# []

# %%
data = [1,2,3,4,5]
plt.plot(data)

# %%
# Create two lists, one called X, one called y, each with 5 numbers in them
x = [1,2,3,4,5]
y = [6,7,8,9,10]
plt.plot(x,y)

# %%
fig,ax = plt.subplots()
ax.plot(x,y);

# %%
import matplotlib.pyplot as plt
X = [2,67,5,43,7]
y = [1,5,78,9,75]

fig , ax = plt.subplots()
ax.plot(X,y)
ax.set(title="This is my first plot",
       xlabel = "X",
       ylabel = "y")
fig.savefig("test-plot.jpeg")

# %%
import numpy as np
# Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X
x = np.linspace(0,101,100)
x
# Out:
# array([  0.        ,   1.02020202,   2.04040404,   3.06060606,
#          4.08080808,   5.1010101 ,   6.12121212,   7.14141414,
#          8.16161616,   9.18181818,  10.2020202 ,  11.22222222,
#         12.24242424,  13.26262626,  14.28282828,  15.3030303 ,
#         16.32323232,  17.34343434,  18.36363636,  19.38383838,
#         20.4040404 ,  21.42424242,  22.44444444,  23.46464646,
#         24.48484848,  25.50505051,  26.52525253,  27.54545455,
#         28.56565657,  29.58585859,  30.60606061,  31.62626263,
#         32.64646465,  33.66666667,  34.68686869,  35.70707071,
#         36.72727273,  37.74747475,  38.76767677,  39.78787879,
#         40.80808081,  41.82828283,  42.84848485,  43.86868687,
#         44.88888889,  45.90909091,  46.92929293,  47.94949495,
#         48.96969697,  49.98989899,  51.01010101,  52.03030303,
#         53.05050505,  54.07070707,  55.09090909,  56.11111111,
#         57.13131313,  58.15151515,  59.17171717,  60.19191919,
#         61.21212121,  62.23232323,  63.25252525,  64.27272727,
#         65.29292929,  66.31313131,  67.33333333,  68.35353535,
#         69.37373737,  70.39393939,  71.41414141,  72.43434343,
#         73.45454545,  74.47474747,  75.49494949,  76.51515152,
#         77.53535354,  78.55555556,  79.57575758,  80.5959596 ,
#         81.61616162,  82.63636364,  83.65656566,  84.67676768,
#         85.6969697 ,  86.71717172,  87.73737374,  88.75757576,
#         89.77777778,  90.7979798 ,  91.81818182,  92.83838384,
#         93.85858586,  94.87878788,  95.8989899 ,  96.91919192,
#         97.93939394,  98.95959596,  99.97979798, 101.        ])

# %%
X = np.linspace(0, 10, 100)
fig,ax = plt.subplots()
ax.plot(X,np.array(X**2));

# %%
fig , ax = plt.subplots()
ax.scatter(X,np.exp(x))

# %%
fig , ax = plt.subplots()
ax.scatter(X,np.sin(X))

# %%
# Create a Python dictionary of 3 of your favourite foods with 
# The keys of the dictionary should be the food name and the values their price
foods = {"Noodles":40,
         "Pizza":100,
         "Donut":60}
fig,ax = plt.subplots()
ax.bar(foods.keys(),foods.values())
ax.set(title="My Favorite Foods",
       xlabel ="Foods",
       ylabel = "Price");

# %%
# Make the same plot as above, except this time make the bars go horizontal
fig ,ax = plt.subplots()
ax.barh(list(foods.keys()),
        list(foods.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
# Create a random NumPy array of 1000 normally distributed numbers using NumPy and save it to X
X = np.random.randn(1000)
fig , ax = plt.subplots()
# Out:
# array([  0.        ,   1.02020202,   2.04040404,   3.06060606,
#          4.08080808,   5.1010101 ,   6.12121212,   7.14141414,
#          8.16161616,   9.18181818,  10.2020202 ,  11.22222222,
#         12.24242424,  13.26262626,  14.28282828,  15.3030303 ,
#         16.32323232,  17.34343434,  18.36363636,  19.38383838,
#         20.4040404 ,  21.42424242,  22.44444444,  23.46464646,
#         24.48484848,  25.50505051,  26.52525253,  27.54545455,
#         28.56565657,  29.58585859,  30.60606061,  31.62626263,
#         32.64646465,  33.66666667,  34.68686869,  35.70707071,
#         36.72727273,  37.74747475,  38.76767677,  39.78787879,
#         40.80808081,  41.82828283,  42.84848485,  43.86868687,
#         44.88888889,  45.90909091,  46.92929293,  47.94949495,
#         48.96969697,  49.98989899,  51.01010101,  52.03030303,
#         53.05050505,  54.07070707,  55.09090909,  56.11111111,
#         57.13131313,  58.15151515,  59.17171717,  60.19191919,
#         61.21212121,  62.23232323,  63.25252525,  64.27272727,
#         65.29292929,  66.31313131,  67.33333333,  68.35353535,
#         69.37373737,  70.39393939,  71.41414141,  72.43434343,
#         73.45454545,  74.47474747,  75.49494949,  76.51515152,
#         77.53535354,  78.55555556,  79.57575758,  80.5959596 ,
#         81.61616162,  82.63636364,  83.65656566,  84.67676768,
#         85.6969697 ,  86.71717172,  87.73737374,  88.75757576,
#         89.77777778,  90.7979798 ,  91.81818182,  92.83838384,
#         93.85858586,  94.87878788,  95.8989899 ,  96.91919192,
#         97.93939394,  98.95959596,  99.97979798, 101.        ])
